# %%
import requests

r = requests.get("https://opendata.epa.gov.tw/ws/Data/AQI/?$format=json", verify=False)
list_of_dicts = r.json()
print(type(r))
print(type(list_of_dicts))
for i in list_of_dicts:
    print(i["County"], i["SiteName"], i["PM2.5"])
    
with open("data_pm25.txt", "w", encoding="utf-8") as file:
    for i in list_of_dicts:
        file.write(i["County"] + " " + i["SiteName"] + " " + i["PM2.5"]+"\n")
# Out:
# D:\Anaconda3-2020.07-Windows-x86_64\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.epa.gov.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# <class 'requests.models.Response'>
# <class 'list'>
# 高雄市 高雄(阿蓮) 24
# 彰化縣 彰化(田尾) 26
# 新北市 新北(樹林) 5
# 臺南市 臺南(北門) 23
# 屏東縣 屏東(琉球) 18
# 臺南市 臺南(麻豆) 23
# 彰化縣 彰化(大城) 20
# 彰化縣 彰化(員林) 20
# 新北市 富貴角 10
# 雲林縣 麥寮 15
# 臺東縣 關山 1
# 澎湖縣 馬公 10
# 金門縣 金門
# 連江縣 馬祖 19
# 南投縣 埔里 20
# 高雄市 復興 26
# 新北市 永和 7
# 南投縣 竹山 29
# 桃園市 中壢 8
# 新北市 三重 12
# 宜蘭縣 冬山 10
# 宜蘭縣 宜蘭 2
# 臺北市 陽明 1
# 花蓮縣 花蓮 6
# 臺東縣 臺東 4
# 屏東縣 恆春 3
# 屏東縣 潮州 43
# 屏東縣 屏東 27
# 高雄市 小港 26
# 高雄市 前鎮 25
# 高雄市 前金 30
# 高雄市 左營 24
# 高雄市 楠梓 27
# 高雄市 林園 28
# 高雄市 大寮 23
# 高雄市 鳳山 28
# 高雄市 仁武 25
# 高雄市 橋頭 25
# 高雄市 美濃 43
# 臺南市 臺南 21
# 臺南市 安南 21
# 臺南市 善化 30
# 臺南市 新營 20
# 嘉義市 嘉義 29
# 雲林縣 臺西
# 嘉義縣 朴子 18
# 嘉義縣 新港 23
# 雲林縣 崙背 26
# 雲林縣 斗六 26
# 南投縣 南投 24
# 彰化縣 二林 22
# 彰化縣 線西 27
# 彰化縣 彰化 23
# 臺中市 西屯 26
# 臺中市 忠明 21
# 臺中市 大里 30
# 臺中市 沙鹿 11
# 臺中市 豐原
# 苗栗縣 三義 16
# 苗栗縣 苗栗 4
# 苗栗縣 頭份 3
# 新竹市 新竹 6
# 新竹縣 竹東 1
# 新竹縣 湖口 9
# 桃園市 龍潭 3
# 桃園市 平鎮 7
# 桃園市 觀音 17
# 桃園市 大園 5
# 桃園市 桃園 4
# 臺北市 大同 6
# 臺北市 松山 7
# 臺北市 古亭 5
# 臺北市 萬華 3
# 臺北市 中山 8
# 臺北市 士林 5
# 新北市 淡水 5
# 新北市 林口 5
# 新北市 菜寮
# 新北市 新莊 6
# 新北市 板橋 7
# 新北市 土城 3
# 新北市 新店 1
# 新北市 萬里
# 新北市 汐止 5
# 基隆市 基隆 4
